# %%
from neuralprophet import NeuralProphet
import pandas as pd

df = pd.read_csv('../data/qty_daily_company.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from neuralprophet import NeuralProphet
#       2 import pandas as pd
#       4 df = pd.read_csv('../data/qty_daily_company.csv')
#
# File e:\Programs\COMPANY\Sashflow\project_future_projection\rnd\.venv\Lib\site-packages\neuralprophet\__init__.py:6
#       4 from ._version import __version__  # noqa: F401
#       5 from .df_utils import split_df  # noqa: F401
# ----> 6 from .forecaster import NeuralProphet  # noqa: F401
#       7 from .TorchProphet import TorchProphet  # noqa: F401
#       8 from .utils import load, save, set_log_level, set_random_seed  # noqa: F401
#
# File e:\Programs\COMPANY\Sashflow\project_future_projection\rnd\.venv\Lib\site-packages\neuralprophet\forecaster.py:12
#       9 from torch.utils.data import DataLoader
#      10 from tqdm import tqdm
# ---> 12 from neuralprophet import configure, df_utils, metrics, time_dataset, time_net, utils
#      13 from neuralprophet.plot_forecast import plot, plot_components
#      14 from neuralprophet.plot_forecast_plotly import plot as plot_plotly
#
# File e:\Programs\COMPANY\Sashflow\project_future_projection\rnd\.venv\Lib\site-packages\neuralprophet\configure.py:17
#      14 import pandas as pd
#      15 import torch
# ---> 17 from neuralprophet import df_utils, utils, utils_torch
#      18 from neuralprophet.custom_loss_metrics import PinballLoss
#      20 log = logging.getLogger("NP.config")
#
# File e:\Programs\COMPANY\Sashflow\project_future_projection\rnd\.venv\Lib\site-packages\neuralprophet\utils.py:16
#      13 import pandas as pd
#      14 import torch
# ---> 16 from neuralprophet import hdays as hdays_part2
#      17 from neuralprophet import utils_torch
#      19 if TYPE_CHECKING:
#
# File e:\Programs\COMPANY\Sashflow\project_future_projection\rnd\.venv\Lib\site-packages\neuralprophet\hdays.py:431
#     423     pass
#     426 # ------------ Holidays in Turkey---------------------
#     427 # This is now in Holidays, but with alias TR instead of the TU that we used.
#     428 # Include TU as an alias for backwards compatibility.
# --> 431 class TU(Turkey):
#     432     pass
#     435 # ------------ Holidays in Pakistan---------------------
#
# File e:\Programs\COMPANY\Sashflow\project_future_projection\rnd\.venv\Lib\site-packages\holidays\registry.py:309, in EntityLoader.__init__(self, path, *args, **kwargs)
#     307 """Set up a lazy loader."""
#     308 if args:
# --> 309     raise TypeError(
#     310         "This is a holidays entity loader class. "
#     311         "For entity inheritance purposes please import a class you "
#     312         "want to derive from directly: e.g., "
#     313         "`from holidays.countries import Entity` or "
#     314         "`from holidays.financial import Entity`."
#     315     )
#     317 entity_path = path.split(".")
#     319 self.entity = None
#
# TypeError: This is a holidays entity loader class. For entity inheritance purposes please import a class you want to derive from directly: e.g., `from holidays.countries import Entity` or `from holidays.financial import Entity`.

# %%
m = NeuralProphet()
m.set_plotting_backend("plotly-static")  # show plots correctly in jupyter notebooks
metrics = m.fit(df)

# %%
predicted = m.predict(df)
forecast = m.predict(df)

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
m.plot_parameters()
